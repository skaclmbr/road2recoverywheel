# %%
import xml.etree.ElementTree as ET

# %%
with open("wheel_template_inkspace.svg", "r", encoding="utf-8-sig") as f:
    tree = ET.parse(f)
    wheel = tree.getroot()

# %%
for child in wheel:
    # print(child.tag, child.attrib)
    if child.attrib["id"] == "diagram blocks":
        for block in child:
            # print(block.tag, block.attrib)
            index_label = block.attrib['{http://www.inkscape.org/namespaces/inkscape}label'][3:]
            print(
                index_label,
                block.attrib['id'])
            # block.attrib['id'] = index_label
# Out:
# 1.1.5 1.1.5
# 6.3.5 6.3.5
# 6.2.5 6.2.5
# 6.1.5 6.1.5
# 5.3.5 5.3.5
# 5.2.5 5.2.5
# 5.1.5 5.1.5
# 4.3.5 4.3.5
# 4.2.5 4.2.5
# 4.1.5 4.1.5
# 3.3.5 3.3.5
# 3.2.5 3.2.5
# 3.1.5 3.1.5
# 2.3.5 2.3.5
# 2.2.5 2.2.5
# 2.1.5 2.1.5
# 1.3.5 1.3.5
# 1.2.5 1.2.5
# 1.3.4 1.3.4
# 2.1.4 2.1.4
# 2.2.4 2.2.4
# 2.3.4 2.3.4
# 3.1.4 3.1.4
# 3.2.4 3.2.4
# 3.3.4 3.3.4
# 4.1.4 4.1.4
# 4.2.4 4.2.4
# 4.3.4 4.3.4
# 5.1.4 5.1.4
# 5.2.4 5.2.4
# 5.3.4 5.3.4
# 6.1.4 6.1.4
# 6.3.4 6.3.4
# 6.2.4 6.2.4
# 1.1.4 1.1.4
# 1.2.4 1.2.4
# 1.3.3 1.3.3
# 2.1.3 2.1.3
# 2.2.3 2.2.3
# 2.3.3 2.3.3
# 3.1.3 3.1.3
# 3.2.3 3.2.3
# 3.3.3 3.3.3
# 4.1.3 4.1.3
# 4.2.3 4.2.3
# 4.3.3 4.3.3
# 5.1.3 5.1.3
# 5.2.3 5.2.3
# 5.3.3 5.3.3
# 6.1.3 6.1.3
# 6.3.3 6.3.3
# 6.2.3 6.2.3
# 1.1.3 1.1.3
# 1.2.3 1.2.3
# 6.1.2 6.1.2
# 5.3.2 5.3.2
# 5.2.2 5.2.2
# 5.1.2 5.1.2
# 4.3.2 4.3.2
# 4.2.2 4.2.2
# 4.1.2 4.1.2
# 3.3.2 3.3.2
# 3.2.2 3.2.2
# 3.1.2 3.1.2
# 2.3.2 2.3.2
# 2.2.2 2.2.2
# 1.3.2 1.3.2
# 2.1.2 2.1.2
# 6.3.2 6.3.2
# 6.2.2 6.2.2
# 1.1.2 1.1.2
# ...

# %%
wheel.write("wheel_template_inkscape_fixed.svg")
